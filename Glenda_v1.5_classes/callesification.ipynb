# %%
import os
import numpy as np
from PIL import Image
from pathlib import Path

# مسیر پوشه ورودی و خروجی
annot_dir = Path("annots")         # پوشه ماسک‌های رنگی
output_dir = Path("masks_numeric") # پوشه ذخیره ماسک عددی
output_dir.mkdir(parents=True, exist_ok=True)

# رنگ‌های کلاس‌ها (دقیقاً مطابق colors.txt)
CLASS_COLORS = [
    [0, 0, 0],         # background
    [190, 62, 204],    # Endo-Peritoneum
    [93, 89, 254],     # Endo-Ovar
    [145, 210, 138],   # Endo-TIE
    [238, 236, 50]     # Endo-Uterus
]

def rgb_to_class(mask_rgb, tolerance=5):
    """تبدیل ماسک RGB به ماسک عددی با تلورانس رنگ"""
    mask_rgb = np.array(mask_rgb)
    mask_class = np.zeros(mask_rgb.shape[:2], dtype=np.uint8)
    for i, color in enumerate(CLASS_COLORS):
        matches = np.all(np.abs(mask_rgb - color) <= tolerance, axis=-1)
        mask_class[matches] = i
    return mask_class

# پردازش و ذخیره همه فایل‌های PNG
for file in annot_dir.glob("*.png"):
    with Image.open(file) as img:
        mask_class = rgb_to_class(img)
        Image.fromarray(mask_class).save(output_dir / file.name)

print(f"✅ تمام ماسک‌ها به صورت عددی ذخیره شدند در: {output_dir}")
# Out:
# ✅ تمام ماسک‌ها به صورت عددی ذخیره شدند در: masks_numeric

# %%
# لیبل‌ها از فایل labels.txt بخونیم (اگر داری)
with open("labels.txt", "r") as f:
    CLASS_LABELS = [line.strip() for line in f.readlines()]

mask_dir = Path("masks_numeric")

for file in sorted(mask_dir.glob("*.png")):
    with Image.open(file) as img:
        mask = np.array(img)
        unique = np.unique(mask)
        class_names = [CLASS_LABELS[i] for i in unique if i < len(CLASS_LABELS)]
        print(f"🟩 {file.name}: {unique.tolist()} => {class_names}")
# Out:
# 🟩 c_100_v_(video_3062.mp4)_f_1458.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_102_v_(video_3119.mp4)_f_1311.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_102_v_(video_3119.mp4)_f_185.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_102_v_(video_3124.mp4)_f_97.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_102_v_(video_3130.mp4)_f_0.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_105_v_(video_3214.mp4)_f_2954.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_108_v_(video_3312.mp4)_f_619.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_10_v_(video_182.mp4)_f_494.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_10_v_(video_184.mp4)_f_22.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_10_v_(video_185.mp4)_f_112.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_10_v_(video_185.mp4)_f_176.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_10_v_(video_186.mp4)_f_200.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_10_v_(video_188.mp4)_f_455.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_113_v_(video_3427.mp4)_f_211.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_114_v_(video_3461.mp4)_f_610.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_117_v_(video_3530.mp4)_f_811.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_117_v_(video_3533.mp4)_f_195.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_120_v_(video_3598.mp4)_f_713.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_120_v_(video_3599.mp4)_f_39.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_121_v_(video_3630.mp4)_f_37.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_123_v_(video_3706.mp4)_f_659.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_125_v_(video_3726.mp4)_f_247.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_127_v_(video_3756.mp4)_f_40.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_12_v_(video_364.mp4)_f_253.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_12_v_(video_365.mp4)_f_174.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_12_v_(video_365.mp4)_f_49.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_12_v_(video_368.mp4)_f_167.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_12_v_(video_368.mp4)_f_261.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_12_v_(video_370.mp4)_f_25.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_12_v_(video_370.mp4)_f_67.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_135_v_(video_4058.mp4)_f_1.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_135_v_(video_4079.mp4)_f_229.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_137_v_(video_4143.mp4)_f_1016.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_137_v_(video_4143.mp4)_f_427.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_137_v_(video_4143.mp4)_f_639.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_13_v_(video_391.mp4)_f_226.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_141_v_(video_4253.mp4)_f_205.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_141_v_(video_4253.mp4)_f_386.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_141_v_(video_4253.mp4)_f_55.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_141_v_(video_4254.mp4)_f_324.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_141_v_(video_4254.mp4)_f_5.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_141_v_(video_4257.mp4)_f_115.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_141_v_(video_4257.mp4)_f_212.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_141_v_(video_4257.mp4)_f_272.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_141_v_(video_4299.mp4)_f_29.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_144_v_(video_4371.mp4)_f_66.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_144_v_(video_4371.mp4)_f_872.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_144_v_(video_4374.mp4)_f_2517.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_144_v_(video_4374.mp4)_f_2771.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_145_v_(video_4391.mp4)_f_27.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_146_v_(video_4410.mp4)_f_2066.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_146_v_(video_4410.mp4)_f_740.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_146_v_(video_4412.mp4)_f_43.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_149_v_(video_4479.mp4)_f_1577.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_149_v_(video_4479.mp4)_f_3137.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_14_v_(video_400.mp4)_f_810.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_14_v_(video_401.mp4)_f_253.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_14_v_(video_401.mp4)_f_90.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_14_v_(video_401.mp4)_f_910.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_14_v_(video_422.mp4)_f_59.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_14_v_(video_425.mp4)_f_118.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_150_v_(video_4517.mp4)_f_109.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_150_v_(video_4518.mp4)_f_28.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_150_v_(video_4520.mp4)_f_132.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_157_v_(video_4727.mp4)_f_0.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_159_v_(video_4770.mp4)_f_4585.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_15_v_(video_449.mp4)_f_2374.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_15_v_(video_449.mp4)_f_2831.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_15_v_(video_450.mp4)_f_623.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_15_v_(video_451.mp4)_f_251.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_15_v_(video_454.mp4)_f_144.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_162_v_(video_4957.mp4)_f_230.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5033.mp4)_f_19.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5033.mp4)_f_547.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5035.mp4)_f_13.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_165_v_(video_5037.mp4)_f_1790.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5038.mp4)_f_161.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5046.mp4)_f_117.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5046.mp4)_f_180.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_165_v_(video_5046.mp4)_f_962.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_168_v_(video_5163.mp4)_f_264.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_169_v_(video_5210.mp4)_f_102.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_169_v_(video_5211.mp4)_f_104.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_16_v_(video_467.mp4)_f_184.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_16_v_(video_471.mp4)_f_220.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_170_v_(video_5222.mp4)_f_64.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_172_v_(video_5281.mp4)_f_1193.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_172_v_(video_5281.mp4)_f_484.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_173_v_(video_5306.mp4)_f_20.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_173_v_(video_5306.mp4)_f_228.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_174_v_(video_5312.mp4)_f_1125.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_174_v_(video_5312.mp4)_f_1319.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_178_v_(video_5419.mp4)_f_794.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_178_v_(video_5426.mp4)_f_90.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_17_v_(video_481.mp4)_f_1292.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_188_v_(video_5701.mp4)_f_226.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_189_v_(video_5727.mp4)_f_14.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_19_v_(video_507.mp4)_f_2389.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_1_v_(video_17.mp4)_f_1232.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_1_v_(video_17.mp4)_f_530.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_1_v_(video_17.mp4)_f_925.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_1_v_(video_7.mp4)_f_1299.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_1_v_(video_7.mp4)_f_36.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_20_v_(video_539.mp4)_f_16.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_20_v_(video_539.mp4)_f_201.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_20_v_(video_539.mp4)_f_305.png: [0, 1, 4] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.4_Endo-Uterus']
# 🟩 c_20_v_(video_539.mp4)_f_560.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_20_v_(video_539.mp4)_f_800.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_21_v_(video_605.mp4)_f_79.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_21_v_(video_607.mp4)_f_46.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_22_v_(video_631.mp4)_f_25.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_22_v_(video_631.mp4)_f_358.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_22_v_(video_631.mp4)_f_706.png: [0, 1, 3] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.3_Endo-TIE']
# 🟩 c_22_v_(video_632.mp4)_f_228.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_22_v_(video_632.mp4)_f_2825.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_22_v_(video_634.mp4)_f_22.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_1006.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_1268.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_13.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_195.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_256.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_397.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_672.mp4)_f_778.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_674.mp4)_f_1579.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_674.mp4)_f_41.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_674.mp4)_f_837.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_23_v_(video_674.mp4)_f_870.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_24_v_(video_693.mp4)_f_136.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_24_v_(video_693.mp4)_f_1495.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_24_v_(video_693.mp4)_f_1606.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_24_v_(video_693.mp4)_f_1630.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_24_v_(video_693.mp4)_f_1697.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_24_v_(video_695.mp4)_f_166.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_24_v_(video_704.mp4)_f_198.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_25_v_(video_774.mp4)_f_1246.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_25_v_(video_774.mp4)_f_608.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_25_v_(video_774.mp4)_f_772.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_25_v_(video_776.mp4)_f_1436.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_25_v_(video_776.mp4)_f_750.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_25_v_(video_777.mp4)_f_33.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_27_v_(video_829.mp4)_f_0.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_28_v_(video_903.mp4)_f_1330.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_903.mp4)_f_1635.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_903.mp4)_f_1761.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_903.mp4)_f_330.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_903.mp4)_f_627.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_903.mp4)_f_853.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_905.mp4)_f_53.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_28_v_(video_907.mp4)_f_73.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_28_v_(video_934.mp4)_f_288.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_295_v_(video_9755.mp4)_f_3595.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_29_v_(video_940.mp4)_f_1371.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_29_v_(video_940.mp4)_f_1635.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_31_v_(video_1002.mp4)_f_499.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_31_v_(video_1002.mp4)_f_91.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_31_v_(video_1004.mp4)_f_869.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_31_v_(video_993.mp4)_f_75.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_31_v_(video_997.mp4)_f_161.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_31_v_(video_998.mp4)_f_85.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_32_v_(video_1044.mp4)_f_1545.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_33_v_(video_1058.mp4)_f_1034.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_33_v_(video_1058.mp4)_f_1254.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_33_v_(video_1058.mp4)_f_1427.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_34_v_(video_1099.mp4)_f_261.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_34_v_(video_1099.mp4)_f_5.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_37_v_(video_1215.mp4)_f_0.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_37_v_(video_1229.mp4)_f_36.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_38_v_(video_1253.mp4)_f_1117.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_39_v_(video_1263.mp4)_f_1769.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_39_v_(video_1263.mp4)_f_481.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_24.mp4)_f_72.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_25.mp4)_f_238.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_25.mp4)_f_249.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_25.mp4)_f_348.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_27.mp4)_f_163.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_27.mp4)_f_338.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_3_v_(video_27.mp4)_f_501.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_3_v_(video_29.mp4)_f_287.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_29.mp4)_f_443.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_29.mp4)_f_480.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_29.mp4)_f_510.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_3_v_(video_29.mp4)_f_627.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_40_v_(video_1275.mp4)_f_184.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_40_v_(video_1277.mp4)_f_411.png: [0, 1, 3] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.3_Endo-TIE']
# 🟩 c_40_v_(video_1281.mp4)_f_262.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_40_v_(video_1286.mp4)_f_126.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_40_v_(video_1286.mp4)_f_775.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_40_v_(video_1288.mp4)_f_17.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_41_v_(video_1297.mp4)_f_140.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_41_v_(video_1297.mp4)_f_500.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_41_v_(video_1297.mp4)_f_826.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_42_v_(video_1320.mp4)_f_565.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_42_v_(video_1320.mp4)_f_653.png: [0, 1, 3] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.3_Endo-TIE']
# 🟩 c_42_v_(video_1322.mp4)_f_276.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_42_v_(video_1322.mp4)_f_471.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_42_v_(video_1322.mp4)_f_624.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_42_v_(video_1323.mp4)_f_183.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_43_v_(video_1363.mp4)_f_1062.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_43_v_(video_1363.mp4)_f_2080.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_43_v_(video_1363.mp4)_f_778.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_43_v_(video_1364.mp4)_f_495.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_43_v_(video_1366.mp4)_f_0.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_44_v_(video_1373.mp4)_f_1199.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_44_v_(video_1373.mp4)_f_201.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_44_v_(video_1373.mp4)_f_211.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_44_v_(video_1373.mp4)_f_215.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_44_v_(video_1373.mp4)_f_903.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_44_v_(video_1377.mp4)_f_212.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1386.mp4)_f_563.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1386.mp4)_f_622.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1386.mp4)_f_753.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1396.mp4)_f_1483.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1396.mp4)_f_2895.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1396.mp4)_f_3007.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_45_v_(video_1396.mp4)_f_408.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_46_v_(video_1405.mp4)_f_299.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_46_v_(video_1405.mp4)_f_36.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_46_v_(video_1405.mp4)_f_568.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_46_v_(video_1406.mp4)_f_108.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_46_v_(video_1406.mp4)_f_209.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_46_v_(video_1406.mp4)_f_426.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_46_v_(video_1406.mp4)_f_81.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_48_v_(video_1525.mp4)_f_685.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_48_v_(video_1525.mp4)_f_759.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_49_v_(video_1561.mp4)_f_1248.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_49_v_(video_1561.mp4)_f_1299.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_49_v_(video_1561.mp4)_f_141.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_49_v_(video_1561.mp4)_f_202.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_49_v_(video_1561.mp4)_f_334.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_49_v_(video_1561.mp4)_f_411.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_4_v_(video_47.mp4)_f_3852.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_4_v_(video_48.mp4)_f_402.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_50_v_(video_1589.mp4)_f_109.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_50_v_(video_1589.mp4)_f_220.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_51_v_(video_1638.mp4)_f_1710.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_51_v_(video_1640.mp4)_f_1162.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_51_v_(video_1640.mp4)_f_25.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_51_v_(video_1640.mp4)_f_535.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_51_v_(video_1640.mp4)_f_643.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_52_v_(video_1656.mp4)_f_2711.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_52_v_(video_1656.mp4)_f_5548.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_55_v_(video_1729.mp4)_f_1915.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_57_v_(video_1790.mp4)_f_557.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_58_v_(video_1853.mp4)_f_1061.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_58_v_(video_1853.mp4)_f_109.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_58_v_(video_1853.mp4)_f_510.png: [0, 1, 3] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.3_Endo-TIE']
# 🟩 c_58_v_(video_1853.mp4)_f_586.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_58_v_(video_1875.mp4)_f_281.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_59_v_(video_1898.mp4)_f_1838.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_59_v_(video_1898.mp4)_f_47.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_59_v_(video_1898.mp4)_f_917.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_5_v_(video_62.mp4)_f_681.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_5_v_(video_64.mp4)_f_712.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_5_v_(video_66.mp4)_f_1754.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_5_v_(video_66.mp4)_f_3.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_60_v_(video_1945.mp4)_f_1392.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_60_v_(video_1945.mp4)_f_366.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_60_v_(video_1945.mp4)_f_52.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_60_v_(video_1946.mp4)_f_1754.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_60_v_(video_1946.mp4)_f_792.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_60_v_(video_1946.mp4)_f_963.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_61_v_(video_1990.mp4)_f_194.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_61_v_(video_1991.mp4)_f_140.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_61_v_(video_1991.mp4)_f_83.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_62_v_(video_2045.mp4)_f_363.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_62_v_(video_2045.mp4)_f_379.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_62_v_(video_2045.mp4)_f_846.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_62_v_(video_2046.mp4)_f_357.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_62_v_(video_2056.mp4)_f_312.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_62_v_(video_2056.mp4)_f_56.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_62_v_(video_2057.mp4)_f_53.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_63_v_(video_2060.mp4)_f_0.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_65_v_(video_2087.mp4)_f_1648.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_65_v_(video_2087.mp4)_f_1816.png: [0, 1, 3] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.3_Endo-TIE']
# 🟩 c_65_v_(video_2087.mp4)_f_2155.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_65_v_(video_2087.mp4)_f_2161.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_65_v_(video_2087.mp4)_f_274.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_65_v_(video_2087.mp4)_f_278.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_65_v_(video_2087.mp4)_f_66.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_65_v_(video_2087.mp4)_f_714.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_65_v_(video_2087.mp4)_f_918.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_69_v_(video_2170.mp4)_f_711.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_69_v_(video_2171.mp4)_f_40.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_112.mp4)_f_1122.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_112.mp4)_f_120.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_112.mp4)_f_174.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_112.mp4)_f_709.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_84.mp4)_f_459.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_84.mp4)_f_695.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_84.mp4)_f_93.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_89.mp4)_f_177.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_89.mp4)_f_340.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_89.mp4)_f_511.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_90.mp4)_f_212.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_90.mp4)_f_684.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_95.mp4)_f_173.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_95.mp4)_f_226.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_6_v_(video_96.mp4)_f_84.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_70_v_(video_2176.mp4)_f_221.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_70_v_(video_2176.mp4)_f_308.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_70_v_(video_2176.mp4)_f_502.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_70_v_(video_2178.mp4)_f_769.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_72_v_(video_2199.mp4)_f_0.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_76_v_(video_2329.mp4)_f_1012.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_76_v_(video_2329.mp4)_f_59.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_76_v_(video_2330.mp4)_f_161.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_76_v_(video_2364.mp4)_f_25.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_77_v_(video_2376.mp4)_f_578.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_77_v_(video_2376.mp4)_f_817.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_77_v_(video_2376.mp4)_f_938.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_77_v_(video_2383.mp4)_f_171.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_77_v_(video_2383.mp4)_f_54.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_79_v_(video_2401.mp4)_f_210.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_79_v_(video_2403.mp4)_f_1001.png: [0, 1, 3] => ['background', '6.1.1.1_Endo-Peritoneum', '6.1.1.3_Endo-TIE']
# 🟩 c_79_v_(video_2404.mp4)_f_688.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_79_v_(video_2405.mp4)_f_42.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_7_v_(video_130.mp4)_f_100.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_7_v_(video_130.mp4)_f_1233.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_7_v_(video_130.mp4)_f_1360.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_7_v_(video_130.mp4)_f_241.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_7_v_(video_130.mp4)_f_411.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_7_v_(video_130.mp4)_f_986.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_7_v_(video_134.mp4)_f_1093.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_7_v_(video_134.mp4)_f_1716.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_7_v_(video_134.mp4)_f_2323.png: [0, 4] => ['background', '6.1.1.4_Endo-Uterus']
# 🟩 c_82_v_(video_2507.mp4)_f_2154.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_85_v_(video_2607.mp4)_f_284.png: [0, 3, 4] => ['background', '6.1.1.3_Endo-TIE', '6.1.1.4_Endo-Uterus']
# 🟩 c_85_v_(video_2607.mp4)_f_733.png: [0, 3, 4] => ['background', '6.1.1.3_Endo-TIE', '6.1.1.4_Endo-Uterus']
# 🟩 c_86_v_(video_2617.mp4)_f_177.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_86_v_(video_2638.mp4)_f_150.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_87_v_(video_2641.mp4)_f_163.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_87_v_(video_2662.mp4)_f_143.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_88_v_(video_2665.mp4)_f_2058.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_88_v_(video_2665.mp4)_f_485.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_8_v_(video_145.mp4)_f_496.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_8_v_(video_146.mp4)_f_298.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_146.mp4)_f_344.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_146.mp4)_f_388.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_147.mp4)_f_11.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_148.mp4)_f_1079.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_148.mp4)_f_164.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_148.mp4)_f_185.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_148.mp4)_f_2515.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_148.mp4)_f_2723.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_148.mp4)_f_973.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_8_v_(video_153.mp4)_f_2707.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_92_v_(video_2749.mp4)_f_25.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_92_v_(video_2787.mp4)_f_199.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_92_v_(video_2787.mp4)_f_462.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_93_v_(video_2819.mp4)_f_1744.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_93_v_(video_2819.mp4)_f_992.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_93_v_(video_2824.mp4)_f_0.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_93_v_(video_2824.mp4)_f_116.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_93_v_(video_2824.mp4)_f_283.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_93_v_(video_2824.mp4)_f_383.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_93_v_(video_2824.mp4)_f_436.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_93_v_(video_2846.mp4)_f_54.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_97_v_(video_2912.mp4)_f_71.png: [0, 2] => ['background', '6.1.1.2_Endo-Ovar']
# 🟩 c_97_v_(video_2915.mp4)_f_114.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_97_v_(video_2915.mp4)_f_16.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_99_v_(video_2998.mp4)_f_256.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_99_v_(video_2998.mp4)_f_73.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_99_v_(video_3000.mp4)_f_51.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_99_v_(video_3006.mp4)_f_102.png: [0, 3] => ['background', '6.1.1.3_Endo-TIE']
# 🟩 c_99_v_(video_3041.mp4)_f_0.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_168.mp4)_f_1146.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_168.mp4)_f_2210.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_168.mp4)_f_515.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_168.mp4)_f_517.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_168.mp4)_f_670.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_169.mp4)_f_79.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_170.mp4)_f_111.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']
# 🟩 c_9_v_(video_172.mp4)_f_0.png: [0, 1] => ['background', '6.1.1.1_Endo-Peritoneum']

# %%
import os

image_dir = "frames"
mask_dir = "masks_numeric"

# همه فایل‌های jpg رو می‌گیریم
image_files = [f for f in os.listdir(image_dir) if f.endswith(".jpg")]

matched_images = []
matched_masks = []

for img_file in image_files:
    mask_file = img_file.replace(".jpg", ".png")
    mask_path = os.path.join(mask_dir, mask_file)
    
    if os.path.exists(mask_path):
        matched_images.append(os.path.join(image_dir, img_file))
        matched_masks.append(mask_path)

print(f"✅ {len(matched_images)} تصویر دارای ماسک هستند.")
print(f"❌ {len(image_files) - len(matched_images)} تصویر بدون ماسک هستند.")
# Out:
# ✅ 373 تصویر دارای ماسک هستند.
# ❌ 0 تصویر بدون ماسک هستند.

# %%
import tensorflow as tf

def random_augment(img, mask):
    # فلیپ افقی
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)

    # فلیپ عمودی
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)

    # چرخش 90 درجه (تصادفی بین 0 و 3 بار)
    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    img = tf.image.rot90(img, k)
    mask = tf.image.rot90(mask, k)

    # تغییر روشنایی (فقط روی تصویر)
    img = tf.image.random_brightness(img, max_delta=0.2)

    return img, mask

# %%
import random

# ترکیب تصاویر و ماسک‌ها
combined = list(zip(matched_images, matched_masks))
random.seed(42)
random.shuffle(combined)

# تقسیم ۸۰٪ آموزش - ۲۰٪ اعتبارسنجی
split_idx = int(0.8 * len(combined))
train_files = combined[:split_idx]
val_files = combined[split_idx:]

# باز کردن دوباره به صورت جدا
train_image_files, train_mask_files = zip(*train_files)
val_image_files, val_mask_files = zip(*val_files)


print(f"📦 آموزش: {len(train_image_files)} نمونه")
print(f"🧪 اعتبارسنجی: {len(train_image_files)} نمونه")
print(train_image_files)
print(train_mask_files)
# Out:
# 📦 آموزش: 298 نمونه
# 🧪 اعتبارسنجی: 298 نمونه
# ('frames/c_40_v_(video_1281.mp4)_f_262.jpg', 'frames/c_34_v_(video_1099.mp4)_f_5.jpg', 'frames/c_23_v_(video_672.mp4)_f_397.jpg', 'frames/c_14_v_(video_401.mp4)_f_910.jpg', 'frames/c_117_v_(video_3530.mp4)_f_811.jpg', 'frames/c_14_v_(video_400.mp4)_f_810.jpg', 'frames/c_7_v_(video_130.mp4)_f_411.jpg', 'frames/c_8_v_(video_148.mp4)_f_185.jpg', 'frames/c_141_v_(video_4257.mp4)_f_115.jpg', 'frames/c_32_v_(video_1044.mp4)_f_1545.jpg', 'frames/c_15_v_(video_450.mp4)_f_623.jpg', 'frames/c_14_v_(video_401.mp4)_f_90.jpg', 'frames/c_49_v_(video_1561.mp4)_f_1248.jpg', 'frames/c_97_v_(video_2915.mp4)_f_114.jpg', 'frames/c_40_v_(video_1286.mp4)_f_126.jpg', 'frames/c_61_v_(video_1990.mp4)_f_194.jpg', 'frames/c_12_v_(video_370.mp4)_f_25.jpg', 'frames/c_174_v_(video_5312.mp4)_f_1319.jpg', 'frames/c_46_v_(video_1406.mp4)_f_81.jpg', 'frames/c_14_v_(video_401.mp4)_f_253.jpg', 'frames/c_4_v_(video_48.mp4)_f_402.jpg', 'frames/c_141_v_(video_4253.mp4)_f_55.jpg', 'frames/c_55_v_(video_1729.mp4)_f_1915.jpg', 'frames/c_21_v_(video_605.mp4)_f_79.jpg', 'frames/c_65_v_(video_2087.mp4)_f_66.jpg', 'frames/c_65_v_(video_2087.mp4)_f_2155.jpg', 'frames/c_65_v_(video_2087.mp4)_f_278.jpg', 'frames/c_23_v_(video_672.mp4)_f_1268.jpg', 'frames/c_1_v_(video_17.mp4)_f_925.jpg', 'frames/c_3_v_(video_27.mp4)_f_338.jpg', 'frames/c_59_v_(video_1898.mp4)_f_47.jpg', 'frames/c_93_v_(video_2819.mp4)_f_1744.jpg', 'frames/c_99_v_(video_3006.mp4)_f_102.jpg', 'frames/c_24_v_(video_693.mp4)_f_1630.jpg', 'frames/c_62_v_(video_2045.mp4)_f_363.jpg', 'frames/c_28_v_(video_934.mp4)_f_288.jpg', 'frames/c_29_v_(video_940.mp4)_f_1371.jpg', 'frames/c_8_v_(video_146.mp4)_f_344.jpg', 'frames/c_85_v_(video_2607.mp4)_f_284.jpg', 'frames/c_41_v_(video_1297.mp4)_f_500.jpg', 'frames/c_1_v_(video_17.mp4)_f_1232.jpg', 'frames/c_93_v_(video_2824.mp4)_f_383.jpg', 'frames/c_61_v_(video_1991.mp4)_f_140.jpg', 'frames/c_28_v_(video_903.mp4)_f_1635.jpg', 'frames/c_59_v_(video_1898.mp4)_f_917.jpg', 'frames/c_48_v_(video_1525.mp4)_f_685.jpg', 'frames/c_174_v_(video_5312.mp4)_f_1125.jpg', 'frames/c_3_v_(video_27.mp4)_f_163.jpg', 'frames/c_44_v_(video_1373.mp4)_f_903.jpg', 'frames/c_28_v_(video_903.mp4)_f_1761.jpg', 'frames/c_178_v_(video_5419.mp4)_f_794.jpg', 'frames/c_135_v_(video_4058.mp4)_f_1.jpg', 'frames/c_146_v_(video_4410.mp4)_f_2066.jpg', 'frames/c_77_v_(video_2376.mp4)_f_817.jpg', 'frames/c_100_v_(video_3062.mp4)_f_1458.jpg', 'frames/c_46_v_(video_1405.mp4)_f_36.jpg', 'frames/c_10_v_(video_186.mp4)_f_200.jpg', 'frames/c_46_v_(video_1406.mp4)_f_426.jpg', 'frames/c_46_v_(video_1406.mp4)_f_108.jpg', 'frames/c_79_v_(video_2401.mp4)_f_210.jpg', 'frames/c_62_v_(video_2056.mp4)_f_312.jpg', 'frames/c_70_v_(video_2176.mp4)_f_221.jpg', 'frames/c_9_v_(video_169.mp4)_f_79.jpg', 'frames/c_9_v_(video_170.mp4)_f_111.jpg', 'frames/c_15_v_(video_451.mp4)_f_251.jpg', 'frames/c_120_v_(video_3598.mp4)_f_713.jpg', 'frames/c_57_v_(video_1790.mp4)_f_557.jpg', 'frames/c_44_v_(video_1373.mp4)_f_201.jpg', 'frames/c_65_v_(video_2087.mp4)_f_2161.jpg', 'frames/c_97_v_(video_2912.mp4)_f_71.jpg', 'frames/c_34_v_(video_1099.mp4)_f_261.jpg', 'frames/c_42_v_(video_1322.mp4)_f_276.jpg', 'frames/c_10_v_(video_182.mp4)_f_494.jpg', 'frames/c_125_v_(video_3726.mp4)_f_247.jpg', 'frames/c_42_v_(video_1320.mp4)_f_653.jpg', 'frames/c_12_v_(video_365.mp4)_f_49.jpg', 'frames/c_9_v_(video_168.mp4)_f_670.jpg', 'frames/c_16_v_(video_467.mp4)_f_184.jpg', 'frames/c_23_v_(video_672.mp4)_f_778.jpg', 'frames/c_23_v_(video_674.mp4)_f_837.jpg', 'frames/c_63_v_(video_2060.mp4)_f_0.jpg', 'frames/c_3_v_(video_25.mp4)_f_238.jpg', 'frames/c_51_v_(video_1640.mp4)_f_1162.jpg', 'frames/c_1_v_(video_7.mp4)_f_36.jpg', 'frames/c_9_v_(video_168.mp4)_f_2210.jpg', 'frames/c_77_v_(video_2383.mp4)_f_171.jpg', 'frames/c_42_v_(video_1323.mp4)_f_183.jpg', 'frames/c_65_v_(video_2087.mp4)_f_1816.jpg', 'frames/c_189_v_(video_5727.mp4)_f_14.jpg', 'frames/c_12_v_(video_364.mp4)_f_253.jpg', 'frames/c_6_v_(video_95.mp4)_f_173.jpg', 'frames/c_102_v_(video_3130.mp4)_f_0.jpg', ' ...
# ('masks_numeric/c_40_v_(video_1281.mp4)_f_262.png', 'masks_numeric/c_34_v_(video_1099.mp4)_f_5.png', 'masks_numeric/c_23_v_(video_672.mp4)_f_397.png', 'masks_numeric/c_14_v_(video_401.mp4)_f_910.png', 'masks_numeric/c_117_v_(video_3530.mp4)_f_811.png', 'masks_numeric/c_14_v_(video_400.mp4)_f_810.png', 'masks_numeric/c_7_v_(video_130.mp4)_f_411.png', 'masks_numeric/c_8_v_(video_148.mp4)_f_185.png', 'masks_numeric/c_141_v_(video_4257.mp4)_f_115.png', 'masks_numeric/c_32_v_(video_1044.mp4)_f_1545.png', 'masks_numeric/c_15_v_(video_450.mp4)_f_623.png', 'masks_numeric/c_14_v_(video_401.mp4)_f_90.png', 'masks_numeric/c_49_v_(video_1561.mp4)_f_1248.png', 'masks_numeric/c_97_v_(video_2915.mp4)_f_114.png', 'masks_numeric/c_40_v_(video_1286.mp4)_f_126.png', 'masks_numeric/c_61_v_(video_1990.mp4)_f_194.png', 'masks_numeric/c_12_v_(video_370.mp4)_f_25.png', 'masks_numeric/c_174_v_(video_5312.mp4)_f_1319.png', 'masks_numeric/c_46_v_(video_1406.mp4)_f_81.png', 'masks_numeric/c_14_v_(video_401.mp4)_f_253.png', 'masks_numeric/c_4_v_(video_48.mp4)_f_402.png', 'masks_numeric/c_141_v_(video_4253.mp4)_f_55.png', 'masks_numeric/c_55_v_(video_1729.mp4)_f_1915.png', 'masks_numeric/c_21_v_(video_605.mp4)_f_79.png', 'masks_numeric/c_65_v_(video_2087.mp4)_f_66.png', 'masks_numeric/c_65_v_(video_2087.mp4)_f_2155.png', 'masks_numeric/c_65_v_(video_2087.mp4)_f_278.png', 'masks_numeric/c_23_v_(video_672.mp4)_f_1268.png', 'masks_numeric/c_1_v_(video_17.mp4)_f_925.png', 'masks_numeric/c_3_v_(video_27.mp4)_f_338.png', 'masks_numeric/c_59_v_(video_1898.mp4)_f_47.png', 'masks_numeric/c_93_v_(video_2819.mp4)_f_1744.png', 'masks_numeric/c_99_v_(video_3006.mp4)_f_102.png', 'masks_numeric/c_24_v_(video_693.mp4)_f_1630.png', 'masks_numeric/c_62_v_(video_2045.mp4)_f_363.png', 'masks_numeric/c_28_v_(video_934.mp4)_f_288.png', 'masks_numeric/c_29_v_(video_940.mp4)_f_1371.png', 'masks_numeric/c_8_v_(video_146.mp4)_f_344.png', 'masks_numeric/c_85_v_(video_2607.mp4)_f_284.png', 'masks_numeric/c_41_v_(video_1297.mp4)_f_500.png', 'masks_numeric/c_1_v_(video_17.mp4)_f_1232.png', 'masks_numeric/c_93_v_(video_2824.mp4)_f_383.png', 'masks_numeric/c_61_v_(video_1991.mp4)_f_140.png', 'masks_numeric/c_28_v_(video_903.mp4)_f_1635.png', 'masks_numeric/c_59_v_(video_1898.mp4)_f_917.png', 'masks_numeric/c_48_v_(video_1525.mp4)_f_685.png', 'masks_numeric/c_174_v_(video_5312.mp4)_f_1125.png', 'masks_numeric/c_3_v_(video_27.mp4)_f_163.png', 'masks_numeric/c_44_v_(video_1373.mp4)_f_903.png', 'masks_numeric/c_28_v_(video_903.mp4)_f_1761.png', 'masks_numeric/c_178_v_(video_5419.mp4)_f_794.png', 'masks_numeric/c_135_v_(video_4058.mp4)_f_1.png', 'masks_numeric/c_146_v_(video_4410.mp4)_f_2066.png', 'masks_numeric/c_77_v_(video_2376.mp4)_f_817.png', 'masks_numeric/c_100_v_(video_3062.mp4)_f_1458.png', 'masks_numeric/c_46_v_(video_1405.mp4)_f_36.png', 'masks_numeric/c_10_v_(video_186.mp4)_f_200.png', 'masks_numeric/c_46_v_(video_1406.mp4)_f_426.png', 'masks_numeric/c_46_v_(video_1406.mp4)_f_108.png', 'masks_numeric/c_79_v_(video_2401.mp4)_f_210.png', 'masks_numeric/c_62_v_(video_2056.mp4)_f_312.png', 'masks_numeric/c_70_v_(video_2176.mp4)_f_221.png', 'masks_numeric/c_9_v_(video_169.mp4)_f_79.png', 'masks_numeric/c_9_v_(video_170.mp4)_f_111.png', 'masks_numeric/c_15_v_(video_451.mp4)_f_251.png', 'masks_numeric/c_120_v_(video_3598.mp4)_f_713.png', 'masks_numeric/c_57_v_(video_1790.mp4)_f_557.png', 'masks_numeric/c_44_v_(video_1373.mp4)_f_201.png', 'masks_numeric/c_65_v_(video_2087.mp4)_f_2161.png', 'masks_numeric/c_97_v_(video_2912.mp4)_f_71.png', 'masks_numeric/c_34_v_(video_1099.mp4)_f_261.png', 'masks_numeric/c_42_v_(video_1322.mp4)_f_276.png', 'masks_numeric/c_10_v_(video_182.mp4)_f_494.png', 'masks_numeric/c_125_v_(video_3726.mp4)_f_247.png', 'masks_numeric/c_42_v_(video_1320.mp4)_f_653.png', 'masks_numeric/c_12_v_(video_365.mp4)_f_49.png', 'masks_numeric/c_9_v_(video_168.mp4)_f_670.png', 'masks_numeric/c_16_v_(video_467.mp4)_f_184.png', 'masks_numeric/c_23_v_(video_672.mp4)_f_778.png', 'mask ...

# %%
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.one_hot(tf.cast(tf.squeeze(y_true, axis=-1), tf.int32), NUM_CLASSES))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.one_hot(tf.cast(tf.squeeze(y_true, axis=-1), tf.int32), NUM_CLASSES))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
import os
import random
import numpy as np
import tensorflow as tf
from PIL import Image
from tensorflow.keras import layers, models, callbacks
import matplotlib.pyplot as plt

# ---------- تنظیمات ----------
IMG_SIZE = 256
NUM_CLASSES = 5
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

# ---------- مسیرها ----------
IMAGE_DIR = "frames"
MASK_DIR = "masks_numeric"

# ---------- خواندن و تقسیم داده ----------
image_files = sorted([os.path.join(IMAGE_DIR, f) for f in os.listdir(IMAGE_DIR)])
mask_files = sorted([os.path.join(MASK_DIR, f) for f in os.listdir(MASK_DIR)])

assert len(image_files) == len(mask_files), "Mismatch in image and mask count."

combined = list(zip(image_files, mask_files))
random.seed(SEED)
random.shuffle(combined)

split_idx = int(0.8 * len(combined))
train_files = combined[:split_idx]
val_files = combined[split_idx:]



class_weights_tensor = tf.constant([
    0.214, 6.454, 11.42, 13.196, 104.479
], dtype=tf.float32)

def weighted_sparse_categorical_loss(y_true, y_pred):
    y_true = tf.cast(tf.squeeze(y_true, axis=-1), tf.int32)
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    scce = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred, from_logits=False)
    weights = tf.gather(class_weights_tensor, y_true)
    weighted_loss = scce * weights
    return tf.reduce_mean(weighted_loss)
import tensorflow as tf

IMG_SIZE = 256

def process_path(image_path, mask_path):
    # خواندن فایل تصویر
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)  # یا decode_png اگر فرمت png است
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.float32) / 255.0

    # خواندن فایل ماسک
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, [IMG_SIZE, IMG_SIZE], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    # ماسک باید صحیح integer باشه، پس cast به uint8 یا int32
    mask = tf.cast(mask, tf.uint8)

    return image, mask

def build_dataset(image_files, mask_files, batch_size, shuffle=True, augment=False):
    dataset = tf.data.Dataset.from_tensor_slices((image_files, mask_files))
    dataset = dataset.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    
    if shuffle:
        dataset = dataset.shuffle(buffer_size=1000)
    
    # اگر augment داری، اینجا می‌تونی augment اضافه کنی
    if augment:
        dataset = dataset.map(random_augment, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset


train_image_files = list(train_image_files)
train_mask_files = list(train_mask_files)
val_image_files = list(val_image_files)
val_mask_files = list(val_mask_files)

train_dataset = build_dataset(train_image_files, train_mask_files, batch_size=BATCH_SIZE, augment=True)
val_dataset = build_dataset(val_image_files, val_mask_files, batch_size=BATCH_SIZE, augment=False)

# ---------- تعریف مدل UNet بزرگ‌تر ----------
def unet_model(input_size=(IMG_SIZE, IMG_SIZE, 3), num_classes=NUM_CLASSES):
    inputs = tf.keras.Input(input_size)

    # Encoder
    c1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(128, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    c3 = layers.Conv2D(256, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, 3, activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D()(c3)

    # Bottleneck
    b = layers.Conv2D(512, 3, activation='relu', padding='same')(p3)
    b = layers.Conv2D(512, 3, activation='relu', padding='same')(b)

    # Decoder
    u3 = layers.UpSampling2D()(b)
    u3 = layers.concatenate([u3, c3])
    c4 = layers.Conv2D(256, 3, activation='relu', padding='same')(u3)
    c4 = layers.Conv2D(256, 3, activation='relu', padding='same')(c4)

    u2 = layers.UpSampling2D()(c4)
    u2 = layers.concatenate([u2, c2])
    c5 = layers.Conv2D(128, 3, activation='relu', padding='same')(u2)
    c5 = layers.Conv2D(128, 3, activation='relu', padding='same')(c5)

    u1 = layers.UpSampling2D()(c5)
    u1 = layers.concatenate([u1, c1])
    c6 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    c6 = layers.Conv2D(64, 3, activation='relu', padding='same')(c6)

    outputs = layers.Conv2D(num_classes, 1, activation='softmax')(c6)

    return models.Model(inputs, outputs)

# ---------- کال‌بک‌ها ----------
early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
checkpoint_cb = callbacks.ModelCheckpoint("unet_checkpoint_best.h5", save_best_only=True, monitor='val_loss')
tensorboard_cb = callbacks.TensorBoard(log_dir="logs_unet", histogram_freq=1, write_images=True)

# ---------- آموزش مدل ----------
model = unet_model()
from tensorflow.keras.optimizers import Adam

learning_rate = 1e-4  # مقدار پیشنهادی، می‌تونی کم و زیاد کنی
optimizer = Adam(learning_rate=learning_rate)

model.compile(
    optimizer=optimizer,
    loss=weighted_sparse_categorical_loss,
    metrics=['accuracy', dice_coefficient, iou_metric]
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748545906.285675  564220 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1748545906.285735  564220 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[early_stop, checkpoint_cb, tensorboard_cb]
)

# ---------- ذخیره مدل ----------
model.save("unet_endometriosis_model_final.keras")

# ---------- ارزیابی روی داده تست ----------
# Out:
# Epoch 1/50
#  3/75 ━━━━━━━━━━━━━━━━━━━━ 18:03 15s/step - accuracy: 0.3396 - dice_coefficient: 0.2066 - iou_metric: 0.1152 - loss: 1.0759

# %%
def visualize_prediction(dataset, model, num_samples=3):
    for image, true_mask in dataset.take(num_samples):
        pred = model.predict(image)
        pred_mask = tf.argmax(pred, axis=-1).numpy()

        batch_size = image.shape[0]
        for i in range(batch_size):
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 3, 1)
            plt.title("Input Image")
            plt.imshow(image[i])
            plt.axis("off")

            plt.subplot(1, 3, 2)
            plt.title("Ground Truth")
            plt.imshow(true_mask[i, ..., 0], cmap='jet', vmin=0, vmax=NUM_CLASSES-1)
            plt.axis("off")

            plt.subplot(1, 3, 3)
            plt.title("Predicted Mask")
            plt.imshow(pred_mask[i], cmap='jet', vmin=0, vmax=NUM_CLASSES-1)
            plt.axis("off")
            plt.tight_layout()
            plt.show()

# نمایش نمونه‌های تست
visualize_prediction(val_dataset, model)

# %%
from tensorflow import keras

# بارگذاری بهترین مدل ذخیره‌شده توسط ModelCheckpoint
model = keras.models.load_model("unet_checkpoint_best.h5")  # یا .keras اگه تغییرش دادی

# %%
import os
from PIL import Image
import numpy as np

mask_dir = "masks_numeric"
all_classes = set()

for f in os.listdir(mask_dir):
    if f.endswith(".png"):
        mask = np.array(Image.open(os.path.join(mask_dir, f)))
        classes = np.unique(mask)
        all_classes.update(classes)

print("📊 تمام کلاس‌های موجود در ماسک‌ها:", sorted(all_classes))

# %%
def apply_color_map(mask):
    rgb_mask = np.zeros((mask.shape[0], mask.shape[1], 3), dtype=np.uint8)
    for i, color in enumerate(CLASS_COLORS):
        rgb_mask[mask == i] = color
    return rgb_mask

def overlay_mask_on_image(image, mask_rgb, alpha=0.5):
    overlay = (image * 255).astype(np.uint8)
    return ((1 - alpha) * overlay + alpha * mask_rgb).astype(np.uint8)

def visualize_prediction2(dataset, model, num_samples=3):
    for image, true_mask in dataset.take(num_samples):
        pred = model.predict(image)
        pred_mask = tf.argmax(pred, axis=-1).numpy()

        batch_size = image.shape[0]
        for i in range(batch_size):
            img_np = image[i].numpy()
            true_mask_rgb = apply_color_map(true_mask[i, ..., 0].numpy())
            pred_mask_rgb = apply_color_map(pred_mask[i])
            overlay_pred = overlay_mask_on_image(img_np, pred_mask_rgb)

            plt.figure(figsize=(18, 5))
            plt.subplot(1, 3, 1)
            plt.title("Input Image")
            plt.imshow(img_np)
            plt.axis("off")

            plt.subplot(1, 3, 2)
            plt.title("Ground Truth Mask")
            plt.imshow(true_mask_rgb)
            plt.axis("off")

            plt.subplot(1, 3, 3)
            plt.title("Overlay: Prediction on Image")
            plt.imshow(overlay_pred)
            plt.axis("off")

            plt.tight_layout()
            plt.show()

# نمایش نمونه‌های تست
visualize_prediction2(val_dataset, model)

# %%
import numpy as np

def analyze_prediction(pred_mask):
    unique_classes = np.unique(pred_mask)
    print("🧪 کلاس‌های پیش‌بینی شده:", unique_classes)

# فرض: pred_mask از visualize_prediction گرفته شده
# مثال روی یک نمونه تست:
for image, true_mask in val_dataset.take(1):
    pred = model.predict(image)
    pred_mask = tf.argmax(pred, axis=-1).numpy()
    analyze_prediction(pred_mask[0])
